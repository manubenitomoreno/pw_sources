# %%
import pandas as pd
import numpy as np

# %%
from os import listdir
from os.path import isfile, join
mypath = r"G:\Mi unidad\walknet_datalake\sources\catastro\level1"
cat = pd.concat([pd.read_parquet(join(mypath, f)) for f in listdir(mypath) if isfile(join(mypath, f)) and "_point" in f and '-MADRID' in f],axis=0)

# %%
cols = ['Parcel Cadastral ID','Building Year Built', 'Property Cadastral ID', 'Property Land Use Level1', 'Part Typology Level1','Part Typology Level2', 'Part Typology Level3','Part Land Use Level1', 'Part Land Use Level2', 'Part Area in Cadastral Terms']

# %%
m = cat[cat['Parcel Cadastral ID'] == '1778604VK4717H'][cols]
#m[m['Part Land Use Level2']=='Parking']
m
# Out:
#        Parcel Cadastral ID  Building Year Built Property Cadastral ID  \
# 579496      1778604VK4717H                 1968   1778604VK4717H-0001
# 579497      1778604VK4717H                 1968   1778604VK4717H-0001
# 579498      1778604VK4717H                 1990   1778604VK4717H-0001
#
#        Property Land Use Level1 Part Typology Level1  \
# 579496                  Housing              Housing
# 579497                  Housing              Housing
# 579498                  Housing                Sport
#
#                  Part Typology Level2        Part Typology Level3  \
# 579496  Urban Single Family Residence  Parking, Storage and Other
# 579497  Urban Single Family Residence            Isolated or Twin
# 579498                      Uncovered               Swimming Pool
#
#        Part Land Use Level1 Part Land Use Level2  Part Area in Cadastral Terms
# 579496  Storage and Parking              Parking                           177
# ...

# %%
from os import listdir
from os.path import isfile, join
mypath = r"G:\Mi unidad\walknet_datalake\sources\catastro\level2"
onlyfiles = [join(mypath, f) for f in listdir(mypath) if isfile(join(mypath, f)) and '_point' in f and '28900' in f]

# %%
d = pd.read_csv(onlyfiles[0],sep=";")

# %%
d.iloc[0]['data']
# Out:
# "{'Destinations - Educational - Basic - Number': '0.0', 'Destinations - Educational - Superior - Number': '0.0', 'Destinations - Healthcare - Multiple - Number': '0.0', 'Destinations - Healthcare - Public - Number': '0.0', 'Destinations - Leisure - Cultural - Number': '0.0', 'Destinations - Leisure - Sport - Number': '0.0', 'Destinations - Leisure - Bars and Restaurants - Number': '0.0', 'Destinations - Leisure - Shows - Number': '0.0', 'Destinations - Public - Multiple - Number': '0.0', 'Destinations - Retail - Mall - Number': '0.0', 'Destinations - Retail - Market or Supermarket - Number': '0.0', 'Destinations - Retail - Stand Alone Retail - Number': '0.0', 'Destinations - Sport - Multiple - Number': '0.0', 'Origins - Housing - Collective Housing - Number': '0.0', 'Origins - Housing - Single Family Residence - Number': '1.0', 'Other - Storage - Number': '0.0', 'Other - Parking - Number': '0.0', 'Other - Industrial - Number': '0.0', 'Other - Office - Number': '0.0', 'Destinations - 
# ...

# %%
import json
for f in onlyfiles:
    print(f)
    d = pd.read_csv(f,sep=";")
    d['data'] = d['data'].astype(str).str.replace("'",'"')
    d['data'] = d['data'].apply(json.loads)
    print(d[d['data'].isna()])

# %%
menu_with_recipes = {}
menu_with_monthly_ingredients = {}

# %%
menu_with_recipes["December"] = {
    "Week 1": [
        "Roasted Beet and Goat Cheese Salad with Walnuts",
        "Herb-Crusted Prime Rib with Red Wine Sauce",
        "Garlic Mashed Potatoes"
    ],
    "Week 2": [
        "Creamy Wild Mushroom Risotto",
        "Honey Glazed Carrots",
        "Spinach and Cranberry Salad with Poppy Seed Dressing"
    ],
    "Week 3": [
        "Lobster Bisque",
        "Baked Ham with Brown Sugar Glaze",
        "Rosemary Roasted Potatoes"
    ],
    "Week 4": [
        "Stuffed Bell Peppers with Ground Beef and Rice",
        "Lemon Garlic Roasted Chicken",
        "Arugula and Pear Salad with Balsamic Vinaigrette"
    ]
}
menu_with_monthly_ingredients["December"] = {
    "Week 1": [
        "Beets",
        "Goat cheese",
        "Walnuts",
        "Prime rib",
        "Red wine",
        "Potatoes"
    ],
    "Week 2": [
        "Wild mushrooms",
        "Carrots",
        "Cranberries",
        "Lobster",
        "Ham",
        "Rosemary"
    ],
    "Week 3": [
        "Lobster",
        "Ham",
        "Potatoes"
    ],
    "Week 4": [
        "Bell peppers",
        "Ground beef",
        "Rice",
        "Chicken",
        "Arugula",
        "Pears"
    ]
}
menu_with_recipes["February"] = {
    "Week 1": [
        "Roasted Cauliflower Steaks with Tahini Sauce",
        "Leek and Potato Soup",
        "Citrus Avocado Salad"
    ],
    "Week 2": [
        "Broccoli and Cheddar Stuffed Baked Potatoes",
        "Brussels Sprouts with Bacon",
        "Strawberry Spinach Salad"
    ],
    "Week 3": [
        "Asparagus and Lemon Risotto",
        "Creamy Strawberry Smoothie",
        "Spinach and Feta Stuffed Chicken Breast"
    ],
    "Week 4": [
        "Quinoa and Vegetable Stir-Fry",
        "Cabbage Rolls with Ground Beef and Rice",
        "Raspberry Kale Smoothie"
    ]
}
menu_with_monthly_ingredients["February"] = {
    "Week 1": [
        "Cauliflower",
        "Leeks",
        "Cauliflower",
        "Leeks",
        "Brussels sprouts"
    ],
    "Week 2": [
        "Asparagus",
        "Strawberries",
        "Spring onions",
        "Spinach",
        "Lettuce"
    ],
    "Week 3": [
        "Strawberries",
        "Leek, potato",
        "Salmon, citrus",
        "Broccoli",
        "Cabbage"
    ],
    "Week 4": [
        "Broccoli",
        "Potatoes",
        "Asparagus",
        "Cauliflower",
        "Mint"
    ]
}

menu_with_recipes["March"] = {
    "Week 1": [
        "Spring Vegetable Pasta Primavera",
        "Spinach and Mint Smoothie",
        "Roasted Asparagus with Lemon"
    ],
    "Week 2": [
        "Strawberry Spinach Salad with Grilled Chicken",
        "Leek and Potato Soup",
        "Citrus Roasted Salmon"
    ],
    "Week 3": [
        "Broccoli and Cheddar Quiche",
        "Creamy Asparagus Soup",
        "Roasted Cauliflower with Cumin"
    ],
    "Week 4": [
        "Lemon Garlic Shrimp Scampi",
        "Quinoa and Spinach Stuffed Peppers",
        "Mint Chocolate Chip Smoothie"
    ]
}
menu_with_monthly_ingredients["March"] = {
    "Week 1": [
        "Asparagus",
        "Mint",
        "Spinach",
        "Lemon"
    ],
    "Week 2": [
        "Strawberries",
        "Leek, potato",
        "Salmon, citrus",
        "Broccoli",
        "Cabbage"
    ],
    "Week 3": [
        "Broccoli",
        "Asparagus",
        "Cauliflower",
        "Leeks",
        "Spinach"
    ],
    "Week 4": [
        "Shrimp",
        "Quinoa",
        "Bell peppers",
        "Lemon",
        "Mint"
    ]
}
menu_with_recipes["April"] = {
    "Week 1": [
        "Roasted Artichokes with Lemon Aioli",
        "Pea and Mint Risotto",
        "Strawberry Spinach Salad"
    ],
    "Week 2": [
        "Stuffed Bell Peppers with Quinoa and Feta",
        "Minted Peas",
        "Asparagus Soup"
    ],
    "Week 3": [
        "Grilled Chicken with Lemon and Thyme",
        "Spinach and Strawberry Smoothie",
        "Roasted Eggplant with Tahini"
    ],
    "Week 4": [
        "Lemon Butter Shrimp Scampi",
        "Creamy Mushroom Risotto",
        "Berry and Kale Smoothie"
    ]
}
menu_with_monthly_ingredients["April"] = {
    "Week 1": [
        "Artichokes",
        "Peas",
        "Mint",
        "Spinach",
        "Strawberries"
    ],
    "Week 2": [
        "Bell peppers",
        "Quinoa",
        "Feta cheese",
        "Peas",
        "Asparagus"
    ],
    "Week 3": [
        "Chicken",
        "Lemon",
        "Thyme",
        "Spinach",
        "Strawberries"
    ],
    "Week 4": [
        "Shrimp",
        "Arborio rice",
        "Mushrooms",
        "Kale",
        "Berries"
    ]
}
menu_with_recipes["May"] = {
    "Week 1": [
        "Caprese Salad with Tomato, Mozzarella, and Basil",
        "Grilled Zucchini with Lemon and Herbs",
        "Pasta Primavera with Asparagus and Peas"
    ],
    "Week 2": [
        "Stuffed Bell Peppers with Quinoa and Spinach",
        "Strawberry Spinach Salad with Balsamic Vinaigrette",
        "Lemon Herb Grilled Chicken"
    ],
    "Week 3": [
        "Tomato and Basil Bruschetta",
        "Grilled Salmon with Lemon-Dill Sauce",
        "Zucchini Noodles with Pesto"
    ],
    "Week 4": [
        "Mango Avocado Salad with Shrimp",
        "Grilled Eggplant with Tahini Sauce",
        "Strawberry Banana Smoothie"
    ]
}
menu_with_monthly_ingredients["May"] = {
    "Week 1": [
        "Tomatoes",
        "Mozzarella",
        "Basil",
        "Zucchini",
        "Asparagus",
        "Peas"
    ],
    "Week 2": [
        "Bell peppers",
        "Quinoa",
        "Spinach",
        "Strawberries",
        "Chicken",
        "Lemon"
    ],
    "Week 3": [
        "Tomatoes",
        "Basil",
        "Salmon",
        "Lemon",
        "Zucchini"
    ],
    "Week 4": [
        "Mango",
        "Avocado",
        "Shrimp",
        "Eggplant",
        "Banana",
        "Strawberries"
    ]
}
menu_with_recipes["May"] = {
    "Week 1": [
        "Caprese Salad with Tomato, Mozzarella, and Basil",
        "Grilled Zucchini with Lemon and Herbs",
        "Pasta Primavera with Asparagus and Peas"
    ],
    "Week 2": [
        "Stuffed Bell Peppers with Quinoa and Spinach",
        "Strawberry Spinach Salad with Balsamic Vinaigrette",
        "Lemon Herb Grilled Chicken"
    ],
    "Week 3": [
        "Tomato and Basil Bruschetta",
        "Grilled Salmon with Lemon-Dill Sauce",
        "Zucchini Noodles with Pesto"
    ],
    "Week 4": [
        "Mango Avocado Salad with Shrimp",
        "Grilled Eggplant with Tahini Sauce",
        "Strawberry Banana Smoothie"
    ]
}
menu_with_monthly_ingredients["May"] = {
    "Week 1": [
        "Tomatoes",
        "Mozzarella",
        "Basil",
        "Zucchini",
        "Asparagus",
        "Peas"
    ],
    "Week 2": [
        "Bell peppers",
        "Quinoa",
        "Spinach",
        "Strawberries",
        "Chicken",
        "Lemon"
    ],
    "Week 3": [
        "Tomatoes",
        "Basil",
        "Salmon",
        "Lemon",
        "Zucchini"
    ],
    "Week 4": [
        "Mango",
        "Avocado",
        "Shrimp",
        "Eggplant",
        "Banana",
        "Strawberries"
    ]
}
menu_with_recipes["July"] = {
    "Week 1": [
        "Watermelon and Feta Salad with Mint",
        "Grilled Chicken Skewers with BBQ Sauce",
        "Corn on the Cob with Chili-Lime Butter"
    ],
    "Week 2": [
        "Cucumber and Tomato Greek Salad",
        "Lemon Herb Grilled Salmon",
        "Summer Berry Salad with Balsamic Glaze"
    ],
    "Week 3": [
        "Caprese Stuffed Avocado",
        "Grilled Shrimp Tacos with Mango Salsa",
        "Grilled Zucchini with Parmesan"
    ],
    "Week 4": [
        "Greek Tzatziki Sauce with Pita Bread",
        "BBQ Pulled Pork Sandwiches",
        "Blueberry Smoothie"
    ]
}
menu_with_monthly_ingredients["July"] = {
    "Week 1": [
        "Watermelon",
        "Feta cheese",
        "Mint",
        "Chicken",
        "Corn"
    ],
    "Week 2": [
        "Cucumber",
        "Tomatoes",
        "Salmon",
        "Berries"
    ],
    "Week 3": [
        "Avocado",
        "Shrimp",
        "Mango",
        "Zucchini"
    ],
    "Week 4": [
        "Greek yogurt",
        "Pork",
        "Blueberries"
    ]
}
menu_with_recipes["July"] = {
    "Week 1": [
        "Watermelon and Feta Salad with Mint",
        "Grilled Chicken Skewers with BBQ Sauce",
        "Corn on the Cob with Chili-Lime Butter"
    ],
    "Week 2": [
        "Cucumber and Tomato Greek Salad",
        "Lemon Herb Grilled Salmon",
        "Summer Berry Salad with Balsamic Glaze"
    ],
    "Week 3": [
        "Caprese Stuffed Avocado",
        "Grilled Shrimp Tacos with Mango Salsa",
        "Grilled Zucchini with Parmesan"
    ],
    "Week 4": [
        "Greek Tzatziki Sauce with Pita Bread",
        "BBQ Pulled Pork Sandwiches",
        "Blueberry Smoothie"
    ]
}
menu_with_monthly_ingredients["July"] = {
    "Week 1": [
        "Watermelon",
        "Feta cheese",
        "Mint",
        "Chicken",
        "Corn"
    ],
    "Week 2": [
        "Cucumber",
        "Tomatoes",
        "Salmon",
        "Berries"
    ],
    "Week 3": [
        "Avocado",
        "Shrimp",
        "Mango",
        "Zucchini"
    ],
    "Week 4": [
        "Greek yogurt",
        "Pork",
        "Blueberries"
    ]
}
menu_with_recipes["September"] = {
    "Week 1": [
        "Apple Walnut Salad with Honey Mustard Dressing",
        "Grilled Pork Chops with Apple Chutney",
        "Butternut Squash Soup"
    ],
    "Week 2": [
        "Grape and Gorgonzola Salad",
        "Roasted Chicken with Grapes and Rosemary",
        "Pumpkin Risotto"
    ],
    "Week 3": [
        "Fig and Prosciutto Crostini",
        "Lamb Kebabs with Fig and Balsamic Glaze",
        "Swiss Chard with Raisins and Pine Nuts"
    ],
    "Week 4": [
        "Baked Apples with Cinnamon and Nutmeg",
        "Stuffed Acorn Squash with Quinoa and Cranberries",
        "Persimmon Salad with Arugula and Pecans"
    ]
}
menu_with_monthly_ingredients["September"] = {
    "Week 1": [
        "Apples",
        "Walnuts",
        "Pork chops",
        "Butternut squash"
    ],
    "Week 2": [
        "Grapes",
        "Gorgonzola cheese",
        "Chicken",
        "Pumpkin"
    ],
    "Week 3": [
        "Figs",
        "Prosciutto",
        "Lamb",
        "Swiss chard"
    ],
    "Week 4": [
        "Cinnamon",
        "Nutmeg",
        "Acorn squash",
        "Quinoa",
        "Cranberries",
        "Persimmons"
    ]
}
menu_with_recipes["October"] = {
    "Week 1": [
        "Mushroom and Spinach Stuffed Portobello Mushrooms",
        "Roasted Butternut Squash Soup",
        "Cranberry Pecan Salad with Balsamic Vinaigrette"
    ],
    "Week 2": [
        "Sweet Potato and Sage Risotto",
        "Grilled Brussels Sprouts with Bacon",
        "Apple Walnut Salad"
    ],
    "Week 3": [
        "Pumpkin and Sage Ravioli",
        "Roasted Turkey with Cranberry Sauce",
        "Roasted Brussels Sprouts with Balsamic Glaze"
    ],
    "Week 4": [
        "Caramelized Onion and Gruyere Tart",
        "Creamy Mushroom and Wild Rice Soup",
        "Arugula and Pear Salad with Lemon Vinaigrette"
    ]
}
menu_with_monthly_ingredients["October"] = {
    "Week 1": [
        "Mushrooms",
        "Spinach",
        "Portobello mushrooms",
        "Butternut squash",
        "Cranberries",
        "Pecans"
    ],
    "Week 2": [
        "Sweet potatoes",
        "Sage",
        "Brussels sprouts",
        "Bacon",
        "Apples",
        "Walnuts"
    ],
    "Week 3": [
        "Pumpkin",
        "Sage",
        "Turkey",
        "Cranberry sauce",
        "Brussels sprouts"
    ],
    "Week 4": [
        "Onions",
        "Gruyere cheese",
        "Mushrooms",
        "Wild rice",
        "Arugula",
        "Pears"
    ]
}
menu_with_recipes["November"] = {
    "Week 1": [
        "Butternut Squash and Apple Soup",
        "Roasted Turkey with Cranberry Sauce",
        "Mashed Sweet Potatoes with Pecan Streusel"
    ],
    "Week 2": [
        "Pumpkin Risotto with Sage and Parmesan",
        "Sautéed Brussels Sprouts with Bacon and Balsamic Glaze",
        "Spinach and Pomegranate Salad"
    ],
    "Week 3": [
        "Creamy Mushroom and Thyme Soup",
        "Baked Ham with Maple Glaze",
        "Honey Roasted Carrots"
    ],
    "Week 4": [
        "Cranberry and Walnut Stuffed Acorn Squash",
        "Garlic Rosemary Roasted Chicken",
        "Quinoa and Kale Salad with Citrus Vinaigrette"
    ]
}
menu_with_monthly_ingredients["November"] = {
    "Week 1": [
        "Butternut squash",
        "Apples",
        "Turkey",
        "Sweet potatoes",
        "Pecans"
    ],
    "Week 2": [
        "Pumpkin",
        "Sage",
        "Parmesan cheese",
        "Brussels sprouts",
        "Bacon",
        "Pomegranate"
    ],
    "Week 3": [
        "Mushrooms",
        "Thyme",
        "Ham",
        "Carrots"
    ],
    "Week 4": [
        "Cranberries",
        "Walnuts",
        "Acorn squash",
        "Chicken",
        "Quinoa",
        "Kale"
    ]
}
menu_with_recipes["December"] = {
    "Week 1": [
        "Roasted Beet and Goat Cheese Salad with Walnuts",
        "Herb-Crusted Prime Rib with Red Wine Sauce",
        "Garlic Mashed Potatoes"
    ],
    "Week 2": [
        "Creamy Wild Mushroom Risotto",
        "Honey Glazed Carrots",
        "Spinach and Cranberry Salad with Poppy Seed Dressing"
    ],
    "Week 3": [
        "Lobster Bisque",
        "Baked Ham with Brown Sugar Glaze",
        "Rosemary Roasted Potatoes"
    ],
    "Week 4": [
        "Stuffed Bell Peppers with Ground Beef and Rice",
        "Lemon Garlic Roasted Chicken",
        "Arugula and Pear Salad with Balsamic Vinaigrette"
    ]
}
menu_with_monthly_ingredients["December"] = {
    "Week 1": [
        "Beets",
        "Goat cheese",
        "Walnuts",
        "Prime rib",
        "Red wine",
        "Potatoes"
    ],
    "Week 2": [
        "Wild mushrooms",
        "Carrots",
        "Cranberries",
        "Lobster",
        "Ham",
        "Rosemary"
    ],
    "Week 3": [
        "Lobster",
        "Ham",
        "Potatoes"
    ],
    "Week 4": [
        "Bell peppers",
        "Ground beef",
        "Rice",
        "Chicken",
        "Arugula",
        "Pears"
    ]
}

menu_with_recipes["January"] = {
    "Week 1": [
        "Citrus Salad with Spinach and Grilled Chicken",
        "Orange-Glazed Carrots",
        "Broccoli Soup"
    ],
    "Week 2": [
        "Kale and Quinoa Stuffed Bell Peppers",
        "Roasted Turnips",
        "Strawberry Spinach Salad"
    ],
    "Week 3": [
        "Cauliflower and Leek Soup",
        "Spinach and Citrus Shrimp Salad",
        "Carrot Ginger Smoothie"
    ],
    "Week 4": [
        "Spinach and Mushroom Omelette",
        "Lemon Roasted Chicken with Brussels Sprouts",
        "Kale Chips"
    ]
}
menu_with_monthly_ingredients["January"] = {
    "Week 1": [
        "Citrus fruits (oranges, grapefruits)",
        "Carrots",
        "Kale, spinach",
        "Broccoli",
        "Cauliflower"
    ],
    "Week 2": [
        "Kale",
        "Bell peppers",
        "Turnips",
        "Strawberries",
        "Spinach"
    ],
    "Week 3": [
        "Cauliflower",
        "Leeks",
        "Asparagus",
        "Strawberries",
        "Spring onions"
    ],
    "Week 4": [
        "Spinach",
        "Mushrooms",
        "Lemon",
        "Brussels sprouts",
        "Kale"
    ]
}

menu_with_recipes["June"] = {
    "Week 1": [
        "Greek Salad with Cucumber, Tomato, and Feta",
        "Grilled Eggplant with Tzatziki Sauce",
        "Lemon Garlic Shrimp Scampi"
    ],
    "Week 2": [
        "Mediterranean Quinoa Salad with Chickpeas",
        "Lamb Kebabs with Mint Yogurt Sauce",
        "Strawberry Spinach Smoothie"
    ],
    "Week 3": [
        "Watermelon and Feta Salad with Balsamic Glaze",
        "Grilled Chicken Souvlaki",
        "Tabbouleh Salad"
    ],
    "Week 4": [
        "Cucumber and Dill Greek Yogurt Dip",
        "Grilled Swordfish with Lemon Herb Butter",
        "Mango Pineapple Smoothie"
    ]
}
menu_with_monthly_ingredients["June"] = {
    "Week 1": [
        "Cucumber",
        "Tomatoes",
        "Feta cheese",
        "Eggplant",
        "Shrimp",
        "Lemon"
    ],
    "Week 2": [
        "Quinoa",
        "Chickpeas",
        "Lamb",
        "Mint",
        "Strawberries"
    ],
    "Week 3": [
        "Watermelon",
        "Feta cheese",
        "Chicken",
        "Mint",
        "Parsley"
    ],
    "Week 4": [
        "Cucumber",
        "Greek yogurt",
        "Swordfish",
        "Mango",
        "Pineapple"
    ]
}
menu_with_recipes["August"] = {
    "Week 1": [
        "Mango Avocado Salad with Lime Dressing",
        "Grilled Steak with Chimichurri Sauce",
        "Grilled Corn and Tomato Salad"
    ],
    "Week 2": [
        "Caprese Stuffed Peppers",
        "Lemon Garlic Butter Shrimp",
        "Peach and Prosciutto Salad"
    ],
    "Week 3": [
        "Greek Orzo Salad",
        "BBQ Pulled Chicken Tacos",
        "Zucchini and Corn Fritters"
    ],
    "Week 4": [
        "Minty Watermelon Cucumber Salad",
        "Grilled Swordfish with Mediterranean Salsa",
        "Pineapple Mango Smoothie"
    ]
}
menu_with_monthly_ingredients["August"] = {
    "Week 1": [
        "Mango",
        "Avocado",
        "Steak",
        "Corn",
        "Tomatoes"
    ],
    "Week 2": [
        "Bell peppers",
        "Shrimp",
        "Peaches",
        "Prosciutto"
    ],
    "Week 3": [
        "Orzo",
        "Chicken",
        "Zucchini",
        "Corn"
    ],
    "Week 4": [
        "Watermelon",
        "Cucumber",
        "Swordfish",
        "Pineapple",
        "Mango"
    ]
}

# %%
pd.DataFrame(menu_with_monthly_ingredients)[['January','February','March','April','May','June','July','August','September','October','November','December']]

# %%
d = pd.read_parquet(r"C:\Users\ManuBenito\Documents\Walknet-DataLake\sources\catastro\level1\28005-ALCALA DE HENARES.parquet")

# %%
d[d['Parcel Cadastral ID'] =='9016801VK6891N']

# %%
d[(d['Property Land Use Level1'].isin(['Shows','Hotel'])) & (d['Part Typology Level1'].isin(['Shows'])) & (d['Part Typology Level2'].isin(['Musical Bars, Dancehalls'])) &
(d['Part Land Use Level1'].isin(['Shows','Retail','Hotel']))  
]

# %%
#d.to_csv(r"C:\Users\ManuBenito\Documents\Walknet-DataLake\sources\catastro\level1\28005-ALCALA DE HENARES.csv",sep=";")

# %%
d = pd.read_parquet(r"C:\Users\ManuBenito\Documents\Walknet-DataLake\sources\catastro\level1\28005-ALCALA DE HENARES.parquet")

# %%
df = pd.DataFrame.from_dict({1:{'origin':"A",'destination':"B",'edge_length':5},
      2:{'origin':"A",'destination':"C",'edge_length':1},
      3:{'origin':"C",'destination':"B",'edge_length':7},
      4:{'origin':"A",'destination':"E",'edge_length':3},
      5:{'origin':"A",'destination':"E",'edge_length':5},
      6:{'origin':"A",'destination':"E",'edge_length':4},
      7:{'origin':"A",'destination':"F",'edge_length':15}},orient='index')

# %%
df = pd.DataFrame.from_dict({1:{'origin':"A",'destination':"B",'edge_length':100}},orient='index')

# %%
def calculate_IJI(dataframe):
    # Sum the edge lengths for each unique pair
    edge_sums = dataframe.groupby(['origin', 'destination'])['edge_length'].sum().reset_index()

    # Calculate the total length of all edges
    total_edge_length = edge_sums['edge_length'].sum()

    # Calculate the proportion of the total edge length that each pair represents
    edge_sums['proportion'] = edge_sums['edge_length'] / total_edge_length

    # Calculate IJI
    edge_sums['iji_component'] = -edge_sums['proportion'] * np.log(edge_sums['proportion'])
    IJI_raw = edge_sums['iji_component'].sum()

    # Normalize IJI to a scale of 0 to 100
    max_IJI = -np.log(1/len(edge_sums))
    IJI_normalized = (IJI_raw / max_IJI) * 100

    return IJI_normalized

# Example usage:
# Assuming df is your DataFrame with columns 'origin', 'destination', and 'edge_length'

# %%
 iji = calculate_IJI(df)

# %%
iji
